# %% [markdown]
# [문제90] last_name, salary 출력해주세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     for line in emp_csv:
#         print(line[2], line[7])
# ```
# [문제91] last_name, last_name 길이를 출력해주세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2], len(line[2]))
# ```
#
# [문제92] employee_id, last_name, salary$*$12 를 출력해주세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[0], line[2], int(line[7])*12)
# ```
# [문제93] last_name, commission_pct를 출력하되 commission_pct값이 ''이면 0으로 출력해주세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         comm = line[8]
#         if len(comm)==0:
#             comm = 0
#         print(line[2], comm)
# ```
# [문제94] last_name을 대문자로, job_id를 소문자로 출력해주세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2].upper(), line[6].lower())
# ```
# [문제95] last_name을 첫글자만 추출해서 소문자로 출력해주세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2][0].lower())
# ```
# [문제96] last_name을 두번째부터 마지막까지만 추출해서 대문자로 출력해주세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2][1:-1].upper())
# ```
# [문제97] 이름을 입력하면 첫글자는 대문자 나머지는 소문자를 출력하는 initcap함수를 이용해 이름을 출력하세요
# ```python
# def initcap(x):
#     return x[0].upper()+x[1:].lower()
# ```
# [문제98] 이름을 입력하면 제일 뒤에 있는 철자는 대문자, 앞의 문자는 소문자로 출력하는 tailcap 함수를 생성하세요.
# ```python
# def tailcap(x):
#     return x[:-1].lower()+x[-1].upper()
# ```
# [문제99] 이름과 급여를 출력하는데 급여를 출력할 때 0 대신 $*$를 출력하세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2], line[7].replace('0','*'))
# ```
# [문제100] 이름, salary * 12 + commission_pct 결과를 출력해주세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         comm = line[8]
#         if len(comm)==0:
#             comm = 0
#         else:
#             comm = float(comm)
#         print(line[2], int(line[7])*(12+comm))
# ```
# [문제101] 이름, 입사한 요일(한글)을 출력해주세요
# ```python
# import csv
# def whatday(date):
#     import datetime as dt
#     days = ['월','화','수','목','금','토','일']
#     day = dt.datetime.strptime(date, '%Y%m%d')
#     return days[day.weekday()]
#
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         print(line[2], whatday(line[5]))
# ```
# [문제102] 이름, 입사한 날짜부터 오늘까지 총 몇일 근부했는지 출력하세요
# ```python
# import csv
# import datetime as dt
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         today = dt.datetime.today()
#         hire = dt.datetime.strptime(line[5],'%Y%m%d')
#         print(line[2], (today-hire).days)
# ```
# ```python
# import csv
# import datetime as dt
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         today = dt.datetime.today()
#         hire = dt.datetime.strptime(line[5],'%Y%m%d')
#         print(line[2], (str(today-hire).split())[0]+'일')
# ```
# [문제103]오늘 부터 이번달 말일까지 몇일 남았는지 출력하세요
# ```python
# import calendar as cld
# import datetime as dt
# today = dt.date.today()
# last = cld.monthrange(today.year, today.month)[1]
# print(last-today.day)
# ```
#
# [문제104] 사원번호가 100번 사원의 사원이름과 급여를 출력하세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     for line in emp_csv:
#         if line[0]=='100':
#             print(line[2], line[7])
# ```
#
# [문제105] 급여가 10000 이상인 사원들의 이름과 급여를 출력하세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if int(line[7])>=10000:
#             print(line[2], line[7])
# ```
#
# [문제106] 2001-01-13일에 입사한 사원의 이름과 입사일을 출력하세요
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if line[5] == '20010113':
#             print(line[2], line[5])
# ```
# ```python
# import csv
# import datetime as dt
#
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if dt.datetime.strptime(line[5],'%Y%m%d').year == dt.datetime.strptime('2001-01-13', '%Y-%m-%d').year:
#             print(line[2], line[5])
# ```
# [문제107] 2002 년도에 입사한 사원들의 이름과 입사일을 출력하세요.
# ```python
# import csv
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if line[5][:4] == '2002':
#             print(line[2], line[5])
# ```
# ```python
# import csv
# import datetime as dt
#
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if dt.datetime.strptime(line[5],'%Y%m%d').year == dt.datetime.strptime('2002', '%Y').year:
#             print(line[2], line[5])
# ```
# [문제108] job이 ST_CLERK 이고 월급 3000 이상인 사원들의 이름과 job, 급여 출력하세요
# ```python
# import csv
# import datetime as dt
# total = 0
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if line[6] == 'ST_CLERK' and int(line[7]) >= 3000:
#             print(line[2], line[6], line[7])
#             total += 1
# print('결과는 총 {} 건 입니다.'.format(total))
# ```
# [문제109] 급여가 2500 에서 3000 사이인 사원들의 이름과 급여를 출력하세요
# ```python
# import csv
# import datetime as dt
# total = 0
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if 2500 <= int(line[7]) <= 3000:
#             print(line[2], line[7])
#             total += 1
# print('결과는 총 {} 건 입니다.'.format(total))
# ```
# [문제110] job AD_VP , AD_PRES 인 사원들의 이름과 월급과 직업을 출력하세요
# ```python
# import csv
# import datetime as dt
# total = 0
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if line[6] in ['AD_VP','AD_PRES']:
#             print(line[2], line[6], line[7])
#             total += 1
# print('결과는 총 {} 건 입니다.'.format(total))
# ```
# [문제111] 직업이 AD_VP , AD_PRES 이 아닌 사원들의 이름과 월급과 직업을  출력하세요
# ```python
# import csv
# import datetime as dt
# total = 0
# with open('c:/data/emp.csv', 'r') as file:
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for line in emp_csv:
#         if line[6] not in ['AD_VP','AD_PRES']:
#             print(line[2], line[6], line[7])
#             total += 1
# print('결과는 총 {} 건 입니다.'.format(total))
# ```

# %% [markdown]
# # 파일입출력
# - ## 파일 열기
#     - ### open()
#         -  open('파일경로', 모드)
#             -  모드
#                 -  r: 읽기
#                 -  w: 쓰기(파일 안의 원본 데이터는 덮어씌워짐)
#                 -  a: 이어쓰기

# %% [markdown]
# - ## 파일 열기
#     - ### with
#         -  파일 객체를 자동으로 닫아주는 문
#         -  with open(경로) as 객체명:
#             ```python
#             txt = ['야!! 가을이다', '오늘 하루 신나게 놀아보자']
#             with open('c:/data/text_new.txt','w') as file:
#                 for i in txt:
#                     file.write(i+'\n')
#             ```
#             ---
#             ```python
#             with open('c:/data/text_new.txt','r') as file:
#                 txt=file.readlines()
#                 for i in txt:
#                     print(i, end='')
#             ```
#             ```
#             야!! 가을이다
#             오늘 하루 신나게 놀아보자
#             ```

# %% [markdown]
# -  ## 파일 닫기
#     -  ### close()
#         -  file객체.close()
# <br></br>
# ```python
# f = open('c:/data/test.txt', 'w')
# for i in range(11, 21):
#     txt = '%d 오늘 하루도 행복하자\n'%i
#     f.write(txt)
# f.close()
# ```

# %% [markdown]
# -  ## 파일 읽기
#     -  ### readline()
#         -  해당 파일을 1줄씩 읽어옴
#         -  파일.readline()
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             data = file.readline() # readline(): 1줄씩 읽어들임
#             print(data)
#             data = file.readline()
#             print(data)
#             file.close()
#             ```
#             ```
#             11 오늘 하루도 행복하자
#
#             12 오늘 하루도 행복하자
#             ```
#             ---
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             while True:
#                 data = file.readline()
#                 if len(data) == 0:
#                     break
#                 print(data)
#             file.close()
#             ```
#             ```
#             11 오늘 하루도 행복하자
#
#             12 오늘 하루도 행복하자
#
#             13 오늘 하루도 행복하자
#
#             14 오늘 하루도 행복하자
#
#             15 오늘 하루도 행복하자
#
#             16 오늘 하루도 행복하자
#
#             17 오늘 하루도 행복하자
#
#             18 오늘 하루도 행복하자
#
#             19 오늘 하루도 행복하자
#
#             20 오늘 하루도 행복하자
#             ```
#             ---
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             while True:
#                 data = file.readline() # readline()은 더이상 읽어올 라인이 없을 때 NONE 리턴
#                 if not data:
#                     break
#                 print(data, end='') #줄간 개행 없앰
#             file.close()
#             ```
#             ```
#             11 오늘 하루도 행복하자
#             12 오늘 하루도 행복하자
#             13 오늘 하루도 행복하자
#             14 오늘 하루도 행복하자
#             15 오늘 하루도 행복하자
#             16 오늘 하루도 행복하자
#             17 오늘 하루도 행복하자
#             18 오늘 하루도 행복하자
#             19 오늘 하루도 행복하자
#             20 오늘 하루도 행복하자
#             ```

# %% [markdown]
# -  ## 파일 읽기
#     -  ### readlines()
#         -  문서의 모든 줄을 읽어 리스트에 저장
#         -  문서.readlines()
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             data = file.readlines() # readlines(): 모든 라인을 읽어 리스트에 저장
#             print(data, end='')
#             file.close()
#             ```
#             ```
#             ['11 오늘 하루도 행복하자\n', '12 오늘 하루도 행복하자\n', '13 오늘 하루도 행복하자\n', '14 오늘 하루도 행복하자\n', '15 오늘 하루도 행복하자\n', '16 오늘 하루도 행복하자\n', '17 오늘 하루도 행복하자\n', '18 오늘 하루도 행복하자\n', '19 오늘 하루도 행복하자\n', '20 오늘 하루도 행복하자\n']
#             ```
#             ---
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             data = file.readlines()
#             for i in data:
#                 print(i, end='')
#             file.close()
#             ```
#             ```
#             11 오늘 하루도 행복하자
#             12 오늘 하루도 행복하자
#             13 오늘 하루도 행복하자
#             14 오늘 하루도 행복하자
#             15 오늘 하루도 행복하자
#             16 오늘 하루도 행복하자
#             17 오늘 하루도 행복하자
#             18 오늘 하루도 행복하자
#             19 오늘 하루도 행복하자
#             20 오늘 하루도 행복하자
#             ```

# %% [markdown]
# -  ## 파일 읽기
#     -  ### read()
#         -  파일 전체를 문자열로 리턴
#         -  파일.read()
#             ```python
#             file = open('c:/data/test.txt', 'r')
#             data = file.read()
#             print(data)
#             file.close()
#             ```
#             ```
#             11 오늘 하루도 행복하자
#             12 오늘 하루도 행복하자
#             13 오늘 하루도 행복하자
#             14 오늘 하루도 행복하자
#             15 오늘 하루도 행복하자
#             16 오늘 하루도 행복하자
#             17 오늘 하루도 행복하자
#             18 오늘 하루도 행복하자
#             19 오늘 하루도 행복하자
#             20 오늘 하루도 행복하자
#             ```

# %% [markdown]
# # 파일 읽기
# ## csv
# -  csv 관련 함수를 제공해주는 패키지
#
# ### reader()
# -  csv파일을 읽어 Iterator 타입인 reader 객체 리턴
# -  csv.reader(파일)
#     ```python
#     import csv
#     file = open('c:/data/emp.csv','r')
#     emp_csv = csv.reader(file)
#     next(emp_csv)
#     for emp_list in emp_csv:
#         print(emp_list)
#     ```
#     ```
#     ['198', 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833', '20070621', 'SH_CLERK', '2600', '', '124', '50']
#     ['199', 'Douglas', 'Grant', 'DGRANT', '650.507.9844', '20080113', 'SH_CLERK', '2600', '', '124', '50']
#     ['200', 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444', '20030917', 'AD_ASST', '4400', '', '101', '10']
#     ['201', 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555', '20040217', 'MK_MAN', '13000', '', '100', '20']
#     ['202', 'Pat', 'Fay', 'PFAY', '603.123.6666', '20050817', 'MK_REP', '6000', '', '201', '20']
#     ... (생략)
#     ```

# %% [markdown]
# ## os
# ### exists()
# -  해당 파일이 존재하는지 확인
# ```python
# import os
# os.path.exists('c:/data/test.txt')
# ```
# ```
# True
# ```
